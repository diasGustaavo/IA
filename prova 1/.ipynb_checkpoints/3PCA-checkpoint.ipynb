# %%
# baseado em https://stackabuse.com/k-nearest-neighbors-algorithm-in-python-and-scikit-learn/
# https://www.codigofluente.com.br/aula-06-scikit-learn-vizinhos-mais-proximos-knn/
# https://colab.research.google.com/github/littlecolumns/ds4j-notebooks/blob/master/classification/notebooks/Correcting%20for%20imbalanced%20datasets.ipynb#scrollTo=jq9376MGvTa7

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import cluster, neighbors, svm, metrics, preprocessing
import plotly.express as px
np.set_printoptions(suppress=True)

# %%
originalDF = pd.read_csv('penguins_size.csv', encoding = "ISO-8859-1")

# %%
from sklearn import preprocessing
 
label_encoder = preprocessing.LabelEncoder()

encodedDF = originalDF.copy()
encodedDF['island']= label_encoder.fit_transform(encodedDF['island'])
encodedDF['sex']= label_encoder.fit_transform(encodedDF['sex'])
encodedDF['species']= label_encoder.fit_transform(encodedDF['species'])

encodedDF = encodedDF[~np.isnan(encodedDF).any(axis=1)]
encodedDF.reset_index(drop=True, inplace=True)
encodedDF
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2              39.1             18.7              181.0
# 1          0       2              39.5             17.4              186.0
# 2          0       2              40.3             18.0              195.0
# 3          0       2              36.7             19.3              193.0
# 4          0       2              39.3             20.6              190.0
# ..       ...     ...               ...              ...                ...
# 337        2       0              47.2             13.7              214.0
# 338        2       0              46.8             14.3              215.0
# 339        2       0              50.4             15.7              222.0
# 340        2       0              45.2             14.8              212.0
# 341        2       0              49.9             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# 1         3800.0    1
# 2         3250.0    1
# 3         3450.0    1
# 4         3650.0    2
# ..           ...  ...
# 337       4925.0    1
# 338       4850.0    1
# 339       5750.0    2
# 340       5200.0    1
# 341       5400.0    2
#
# [342 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaledArr = StandardScaler().fit_transform(encodedDF.loc[:, ['island','culmen_length_mm','culmen_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex']].values)
scaledDF = pd.DataFrame(data = scaledArr, columns = ['island','culmen_length_mm','culmen_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex']) 
scaledDF
# Out:
#        island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    1.852870         -0.884499         0.785449          -1.418347
# 1    1.852870         -0.811126         0.126188          -1.062250
# 2    1.852870         -0.664380         0.430462          -0.421277
# 3    1.852870         -1.324737         1.089724          -0.563715
# 4    1.852870         -0.847812         1.748985          -0.777373
# ..        ...               ...              ...                ...
# 337 -0.914298          0.601305        -1.750171           0.931890
# 338 -0.914298          0.527932        -1.445897           1.003109
# 339 -0.914298          1.188289        -0.735923           1.501644
# 340 -0.914298          0.234440        -1.192335           0.789451
# 341 -0.914298          1.096572        -0.533073           0.860670
#
#      body_mass_g       sex
# 0      -0.564142  0.846836
# 1      -0.501703 -0.974660
# 2      -1.188532 -0.974660
# 3      -0.938776 -0.974660
# 4      -0.689020  0.846836
# ..           ...       ...
# 337     0.903175 -0.974660
# 338     0.809516 -0.974660
# 339     1.933419  0.846836
# 340     1.246590 -0.974660
# 341     1.496346  0.846836
#
# [342 rows x 6 columns]

# %%
scaledDF = pd.concat([scaledDF, encodedDF[['species']]], axis = 1)
scaledDF
# Out:
#        island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    1.852870         -0.884499         0.785449          -1.418347
# 1    1.852870         -0.811126         0.126188          -1.062250
# 2    1.852870         -0.664380         0.430462          -0.421277
# 3    1.852870         -1.324737         1.089724          -0.563715
# 4    1.852870         -0.847812         1.748985          -0.777373
# ..        ...               ...              ...                ...
# 337 -0.914298          0.601305        -1.750171           0.931890
# 338 -0.914298          0.527932        -1.445897           1.003109
# 339 -0.914298          1.188289        -0.735923           1.501644
# 340 -0.914298          0.234440        -1.192335           0.789451
# 341 -0.914298          1.096572        -0.533073           0.860670
#
#      body_mass_g       sex  species
# 0      -0.564142  0.846836        0
# 1      -0.501703 -0.974660        0
# 2      -1.188532 -0.974660        0
# 3      -0.938776 -0.974660        0
# 4      -0.689020  0.846836        0
# ..           ...       ...      ...
# 337     0.903175 -0.974660        2
# 338     0.809516 -0.974660        2
# 339     1.933419  0.846836        2
# 340     1.246590 -0.974660        2
# 341     1.496346  0.846836        2
#
# [342 rows x 7 columns]

# %%
corr = scaledDF.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_75d0e_row0_col0,#T_75d0e_row1_col1,#T_75d0e_row2_col2,#T_75d0e_row3_col3,#T_75d0e_row4_col4,#T_75d0e_row5_col5,#T_75d0e_row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_75d0e_row0_col1,#T_75d0e_row0_col4,#T_75d0e_row2_col3,#T_75d0e_row2_col6,#T_75d0e_row6_col0,#T_75d0e_row6_col2,#T_75d0e_row6_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_75d0e_row0_col2{
#             background-color:  #f39778;
#             color:  #000000;
#         }#T_75d0e_row0_col3{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_75d0e_row0_col5{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_75d0e_row0_col6{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_75d0e_row1_col0{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_75d0e_row1_col2{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_75d0e_row1_col3{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_75d0e_row1_col4{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }#T_75d0e_row1_col5{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_75d0e_row1_col6{
#             background-color:  #e46e56;
#             color:  #000000;
#         }#T_75d0e_row2_col0{
#             background-color:  #f59f80;
#             color:  #000000;
#         }#T_75d0e_row2_col1{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_75d0e_row2_col4{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_75d0e_row2_col5{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_75d0e_row3_col0{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_75d0e_row3_col1{
#             background-color:  #f59c7d;
#             color:  #000000;
#         }#T_75d0e_row3_col2{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_75d0e_row3_col4,#T_75d0e_row3_col6{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }#T_75d0e_row3_col5{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_75d0e_row4_col0{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_75d0e_row4_col1{
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }#T_75d0e_row4_col2{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_75d0e_row4_col3{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }#T_75d0e_row4_col5{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_75d0e_row4_col6{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_75d0e_row5_col0{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_75d0e_row5_col1{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_75d0e_row5_col2{
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }#T_75d0e_row5_col3{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_75d0e_row5_col4{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_75d0e_row5_col6{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_75d0e_row6_col1{
#             background-color:  #ed8366;
#             color:  #000000;
#         }#T_75d0e_row6_col3{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_75d0e_row6_col4{
#             background-color:  #e57058;
#             color:  #000000;
#         }</style><table id="T_75d0e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >island</th>        <th class="col_heading level0 col1" >culmen_length_mm</th>        <th class="col_heading level0 col2" >culmen_depth_mm</th>        <th class="col_heading level0 col3" >flipper_length_mm</th>        <th class="col_heading level0 col4" >body_mass_g</th>        <th class="col_heading level0 col5" >sex</th>        <th class="col_heading level0 col6" >species</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75d0e_level0_row0" class="row_heading level0 row0" >island</th>
#                         <td id="T_75d0e_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_75d0e_row0_col1" class="data row0 col1" >-0.353647</td>
#                         <td id="T_75d0e_row0_col2" class="data row0 col2" >0.571035</td>
#                         <td id="T_75d0e_row0_col3" class="data row0 col3" >-0.565825</td>
#                         <td id="T_75d0e_row0_col4" class="data row0 col4" >-0.561515</td>
#                         <td id="T_75d0e_row0_col5" class="data row0 col5" >0.037362</td>
#                         <td id="T_75d0e_row0_col6" class="data row0 col6" >-0.633150</td>
#             </tr>
#             <tr>
#                         <th id="T_75d0e_level0_row1" class="row_heading level0 row1" >culmen_length_mm</th>
#                         <td id="T_75d0e_row1_col0" class="data row1 col0" >-0.353647</td>
#                         <td id="T_75d0e_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_75d0e_row1_col2" class="data row1 col2" >-0.235053</td>
#                         <td id="T_75d0e_row1_col3" class="data row1 col3" >0.656181</td>
#                         <td id="T_75d0e_row1_col4" class="data row1 col4" >0.595110</td>
#                         <td id="T_75d0e_row1_col5" class="data row1 col5" >0.269434</td>
#                         <td id="T_75d0e_row1_col6" class="data row1 col6" >0.731369</td>
#             </tr>
#             <tr>
#                         <th id="T_75d0e_level0_row2" class="row_heading level0 row2" >culmen_depth_mm</th>
#                         <td id="T_75d0e_row2_col0" class="data row2 col0" >0.571035</td>
#                         <td id="T_75d0e_row2_col1" class="data row2 col1" >-0.235053</td>
#                         <td id="T_75d0e_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_75d0e_row2_col3" class="data row2 col3" >-0.583851</td>
#                         <td id="T_75d0e_row2_col4" class="data row2 col4" >-0.471916</td>
#                         <td id="T_75d0e_row2_col5" class="data row2 col5" >0.322860</td>
#                         <td id="T_75d0e_row2_col6" class="data row2 col6" >-0.744076</td>
#             </tr>
#             <tr>
#                         <th id="T_75d0e_level0_row3" class="row_heading level0 row3" >flipper_length_mm</th>
#                         <td id="T_75d0e_row3_col0" class="data row3 col0" >-0.565825</td>
#                         <td id="T_75d0e_row3_col1" class="data row3 col1" >0.656181</td>
#                         <td id="T_75d0e_row3_col2" class="data row3 col2" >-0.583851</td>
#                         <td id="T_75d0e_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_75d0e_row3_col4" class="data row3 col4" >0.871202</td>
#                         <td id="T_75d0e_row3_col5" class="data row3 col5" >0.197440</td>
#                         <td id="T_75d0e_row3_col6" class="data row3 col6" >0.854307</td>
#             </tr>
#             <tr>
#                         <th id="T_75d0e_level0_row4" class="row_heading level0 row4" >body_mass_g</th>
#                         <td id="T_75d0e_row4_col0" class="data row4 col0" >-0.561515</td>
#                         <td id="T_75d0e_row4_col1" class="data row4 col1" >0.595110</td>
#                         <td id="T_75d0e_row4_col2" class="data row4 col2" >-0.471916</td>
#                         <td id="T_75d0e_row4_col3" class="data row4 col3" >0.871202</td>
#                         <td id="T_75d0e_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td

# %%
y = scaledDF.loc[:, ['species']].values
X = scaledDF.loc[:, ['island','culmen_length_mm','culmen_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex']].values
# X

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents, columns = ['Componente Principal 1', 'Componente Principal 2'])

finalDf = pd.concat([principalDf, scaledDF[['species']]], axis = 1)
finalDf['species'] = label_encoder.inverse_transform(scaledDF['species'])
finalDf
# Out:
#      Componente Principal 1  Componente Principal 2 species
# 0                 -2.330493                1.123742  Adelie
# 1                 -2.043549               -0.534049  Adelie
# 2                 -2.109898               -0.419954  Adelie
# 3                 -2.566098               -0.221928  Adelie
# 4                 -2.401836                1.643673  Adelie
# ..                      ...                     ...     ...
# 337                2.092390               -1.520909  Gentoo
# 338                1.940461               -1.394787  Gentoo
# 339                2.968940                0.724001  Gentoo
# 340                1.838221               -1.280319  Gentoo
# 341                2.304560                0.703120  Gentoo
#
# [342 rows x 3 columns]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Componente Principal 1', fontsize = 15)
ax.set_ylabel('Componente Principal 2', fontsize = 15)
ax.set_title('PCA com 2 componentes', fontsize = 20)
targets = ['Adelie', 'Chinstrap', 'Gentoo']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['species'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'Componente Principal 1']
               , finalDf.loc[indicesToKeep, 'Componente Principal 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)

principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents, columns = ['Componente Principal 1', 'Componente Principal 2', 'Componente Principal 3'])

finalDf = pd.concat([principalDf, scaledDF[['species']]], axis = 1)
# finalDf['species'] = label_encoder.inverse_transform(scaledDF['species'])
finalDf
# Out:
#      Componente Principal 1  Componente Principal 2  Componente Principal 3  \
# 0                 -2.330493                1.123742               -0.120542
# 1                 -2.043549               -0.534049                0.735700
# 2                 -2.109898               -0.419954                1.019183
# 3                 -2.566098               -0.221928                0.521244
# 4                 -2.401836                1.643673                0.033013
# ..                      ...                     ...                     ...
# 337                2.092390               -1.520909                0.296622
# 338                1.940461               -1.394787                0.278114
# 339                2.968940                0.724001               -0.128246
# 340                1.838221               -1.280319               -0.006948
# 341                2.304560                0.703120               -0.187518
#
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 337        2
# 338        2
# 339        2
# 340        2
# 341        2
#
# [342 rows x 4 columns]

# %%
# import relevant libraries for 3d graph
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10,10))
 
# choose projection 3d for creating a 3d graph
axis = fig.add_subplot(111, projection='3d')
 
# x[:,0]is pc1,x[:,1] is pc2 while x[:,2] is pc3
axis.scatter(finalDf['Componente Principal 1'],finalDf['Componente Principal 2'],finalDf['Componente Principal 3'], c=finalDf['species'], cmap='plasma')
axis.set_xlabel("PC1", fontsize=10)
axis.set_ylabel("PC2", fontsize=10)
axis.set_zlabel("PC3", fontsize=10)
#type(finalDf['Componente Principal 1'])
# Out:
# Text(0.5, 0, 'PC3')
