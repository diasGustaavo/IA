# %%
# baseado em https://stackabuse.com/k-nearest-neighbors-algorithm-in-python-and-scikit-learn/
# https://www.codigofluente.com.br/aula-06-scikit-learn-vizinhos-mais-proximos-knn/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import cluster, neighbors, svm, metrics, preprocessing

# %%
df = pd.read_csv('drug200.csv', encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, 5].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
X_train
# Out:
# array([[41, 'F', 'LOW', 'NORMAL', 18.739],
#        [60, 'M', 'HIGH', 'HIGH', 13.934],
#        [23, 'M', 'NORMAL', 'HIGH', 12.26],
#        [29, 'F', 'HIGH', 'HIGH', 29.45],
#        [57, 'F', 'NORMAL', 'NORMAL', 25.893],
#        [25, 'M', 'NORMAL', 'HIGH', 19.011],
#        [53, 'M', 'LOW', 'HIGH', 22.963],
#        [49, 'M', 'LOW', 'NORMAL', 13.598],
#        [64, 'M', 'HIGH', 'NORMAL', 20.932],
#        [49, 'F', 'NORMAL', 'HIGH', 16.275],
#        [18, 'F', 'HIGH', 'NORMAL', 24.276],
#        [65, 'M', 'HIGH', 'NORMAL', 34.997],
#        [24, 'M', 'NORMAL', 'HIGH', 25.786],
#        [74, 'M', 'HIGH', 'HIGH', 9.567],
#        [42, 'M', 'LOW', 'HIGH', 20.013],
#        [47, 'F', 'LOW', 'HIGH', 10.067],
#        [49, 'M', 'LOW', 'NORMAL', 11.014],
#        [39, 'M', 'LOW', 'NORMAL', 13.938],
#        [29, 'M', 'HIGH', 'HIGH', 12.856],
#        [23, 'M', 'NORMAL', 'HIGH', 31.686],
#        [37, 'F', 'LOW', 'NORMAL', 12.006],
#        [18, 'F', 'HIGH', 'HIGH', 37.188],
# ...

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

scaler = StandardScaler()

temp = np.reshape(X_train[:, 4],(-1,1))
temp2 = np.reshape(X_test[:, 4],(-1,1))

scaler.fit(temp)

X_train = scaler.transform(temp)
X_test = scaler.transform(temp2)

# %%
X_train
